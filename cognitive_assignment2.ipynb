# %% [markdown]
# 1. Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L (10
# numbers in list now).

# %% [markdown]
# i. Print L

# %%
roll=1024170288
l=[]
while roll>0:
  rem=roll%10
  l.append(rem*10)
  roll//=10
l.reverse()
print(l)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 20, 80, 80]

# %% [markdown]
# ii. Add two numbers of your choice to L — one using append() and one using insert() at a specific position.
# Print L after each and explain in a comment what changed.

# %%
l.append(50)
print(l)             #append adds element at the end of the list

l.insert(3,100)
print(l)             #insert adds element at specific index
# Out:
# [10, 0, 20, 40, 10, 70, 0, 20, 80, 80, 50]
# [10, 0, 20, 100, 40, 10, 70, 0, 20, 80, 80, 50]

# %% [markdown]
# iii. Remove two elements from L — one using remove() and one using pop(). Print L after each.

# %%
l.remove(80)
print(l)

l.pop(3)
print(l)
# Out:
# [10, 0, 20, 100, 40, 10, 70, 0, 20, 80, 50]
# [10, 0, 20, 40, 10, 70, 0, 20, 80, 50]

# %%
l.sort()
print(l)

l.sort(reverse=True)
print(l)
# Out:
# [0, 0, 10, 10, 20, 20, 40, 50, 70, 80]
# [80, 70, 50, 40, 20, 20, 10, 10, 0, 0]

# %%
print(l[:3])

print(l[-3:])
# Out:
# [80, 70, 50]
# [10, 0, 0]

# %% [markdown]
# vi. Use list comprehension to create a new list containing only the elements of L that are greater than the
# average of L.

# %%
avg=sum(l)/len(l)
print(avg)

new=[]
for i in l:
  if i>avg:
    new.append(i)
print(new)
# Out:
# 30.0
# [80, 70, 50, 40]

# %% [markdown]
# 2. Create a tuple named scores containing 8 marks: use the first 8 values from your list L in Q1.

# %% [markdown]
# i. Find the highest score and its index in the tuple, and the lowest score and how many times it appears.

# %%
scores=tuple(l[:8])
print(scores)

highest_score=max(scores)
print(highest_score)

highest_index=scores.index(highest_score)
print(highest_index)

lowest_score=min(scores)
print(lowest_score)

lowest_count=scores.count(lowest_score)
print(lowest_count)
# Out:
# (80, 70, 50, 40, 20, 20, 10, 10)
# 80
# 0
# 10
# 2

# %% [markdown]
# ii. Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place —
# explain why in a one-line comment, referring to tuple immutability).

# %%
reversed_scores=list(reversed(scores))
print(reversed_scores)   ## Tuples are immutable.They cannot be reversed in place.
# Out:
# [10, 10, 20, 20, 40, 50, 70, 80]

# %% [markdown]
# iii. Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present
# message if not.

# %%
score = int(input("Enter a score: "))

if score in scores:
    print("First occurrence index:", scores.index(score))
else:
    print("Score is not present in the tuple.")
# Out:
# Enter a score: 50
# First occurrence index: 2

# %% [markdown]
# iv. Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error
# Python raises, and explain in one line why this happens and how it differs from a list.

# %%
scores[0]=100
print(scores)   #tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2582/1978700670.py in <cell line: 0>()
# ----> 1 scores[0]=100
#       2 print(scores)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# v. Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a
# single line of unpacking.

# %%
first_score,second_score,*remaining_score=scores
print("first score: ",first_score)
print("second score: ",second_score)
print("remaing : ",remaining_score)
# Out:
# first score:  80
# second score:  70
# remaing :  [50, 40, 20, 20, 10, 10]

# %% [markdown]
# 3. Set the random seed to your own roll number using random.seed(your_roll_number) before generating
# your numbers — this keeps your list random-looking but reproducible and unique to you (a different seed
# produces a different list, so this cannot be copied from a classmate).

# %% [markdown]
# i. Generate a list of 100 random numbers between 100 and 900 (inclusive).

# %%
import random
roll=1024170288
random.seed(roll)

numbers=[random.randint(100,900) for _ in range(100) ]
print(numbers)
# Out:
# [860, 857, 279, 854, 218, 774, 161, 542, 670, 411, 354, 256, 614, 515, 494, 506, 640, 167, 369, 562, 842, 225, 845, 692, 469, 517, 250, 861, 602, 173, 567, 850, 828, 174, 372, 135, 114, 827, 170, 871, 175, 723, 390, 287, 897, 340, 597, 735, 302, 243, 820, 484, 373, 487, 157, 173, 397, 214, 415, 662, 663, 766, 794, 659, 394, 784, 696, 258, 635, 139, 514, 383, 399, 734, 513, 275, 753, 192, 859, 160, 546, 369, 695, 375, 175, 674, 507, 793, 211, 646, 729, 388, 419, 752, 293, 800, 306, 741, 233, 522]

# %% [markdown]
# ii. Count and print all odd numbers in the list.

# %%
odd_nums=[]
for i in numbers:
  if i%2!=0:
    odd_nums.append(i)
print(odd_nums)

print(len(odd_nums))
# Out:
# [857, 279, 161, 411, 515, 167, 369, 225, 845, 469, 517, 861, 173, 567, 135, 827, 871, 175, 723, 287, 897, 597, 735, 243, 373, 487, 157, 173, 397, 415, 663, 659, 635, 139, 383, 399, 513, 275, 753, 859, 369, 695, 375, 175, 507, 793, 211, 729, 419, 293, 741, 233]
# 52

# %% [markdown]
# iii. Count and print all even numbers in the list.

# %%
even_nums=[]
for i in numbers:
  if i%2==0:
    even_nums.append(i)
print(even_nums)

print(len(even_nums))
# Out:
# [860, 854, 218, 774, 542, 670, 354, 256, 614, 494, 506, 640, 562, 842, 692, 250, 602, 850, 828, 174, 372, 114, 170, 390, 340, 302, 820, 484, 214, 662, 766, 794, 394, 784, 696, 258, 514, 734, 192, 160, 546, 674, 646, 388, 752, 800, 306, 522]
# 48

# %% [markdown]
# iv. Count and print all prime numbers in the list, and additionally build the actual list of prime numbers
# found using list comprehension.

# %%
prime_num=[]
for i in numbers:
  count=0
  for j in range(1,i+1):
    if i%j==0:
      count+=1
  if count==2:
    prime_num.append(i)
print(prime_num)

print(len(prime_num))
# Out:
# [857, 167, 173, 827, 373, 487, 157, 173, 397, 659, 139, 383, 859, 211, 419, 293, 233]
# 17

# %% [markdown]
# v. Print the number that occurs most frequently in your list, and how many times it occurs

# %%
freq={}
for i in numbers:
  if i in freq:
    freq[i]+=1
  else:
    freq[i]=1
num=0
maxi=0

for x in freq:
  if freq[x]>maxi:
    num=x
    maxi=freq[x]

print("most frequent number: ",num)
print("number of times it occur: ",maxi)
# Out:
# most frequent number:  369
# number of times it occur:  2

# %% [markdown]
# 4. Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for
# each digit} and set B = {digit × 9 for each digit}. Print both sets.

# %%
roll=1024170288
digits=['1','0','2','4','1','7','0','2','8','8']
a=[]
b=[]
for i in digits:
  a.append(int(i)*7)
  b.append(int(i)*9)
a=set(a)
b=set(b)
print(a)
print(b)
# Out:
# {0, 7, 14, 49, 56, 28}
# {0, 36, 72, 9, 18, 63}

# %% [markdown]
# vi. Find the union of A and B — all unique values across both sets.

# %%
union=a.union(b)
print(union)
# Out:
# {0, 36, 7, 72, 9, 14, 49, 18, 56, 28, 63}

# %% [markdown]
# vii. Find the intersection of A and B — values common to both.

# %%
intersect=a.intersection(b)
print(intersect)
# Out:
# {0}

# %% [markdown]
# viii. Find A − B and B − A separately (not combined) using difference(), and explain in one line how this
# differs from symmetric_difference().

# %%
a_b=a.difference(b)
print(a_b)
b_a=b.difference(a)
print(b_a)

## difference() gives elements present in one set but not in the other
# symmetric_difference() gives elements present in either set but not in both.
# Out:
# {7, 14, 49, 56, 28}
# {36, 72, 9, 18, 63}

# %% [markdown]
# ix. Find the symmetric difference of A and B.

# %%
symm=a.symmetric_difference(b)
print(symm)
# Out:
# {7, 72, 9, 14, 18, 28, 36, 49, 56, 63}

# %% [markdown]
# x. Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset()

# %%
print("Is a subset of b:", a.issubset(b))
print("Is b superset of a:", b.issuperset(a))
# Out:
# Is a subset of b: False
# Is b superset of a: False

# %% [markdown]
# xi. Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain
# in one line why discard() is safer than remove() when you're not sure the value exists.

# %%
x=int(input("enter a value: "))
print("set a before discard: ",a)
a.discard(x)
print("set a after discard: ",a)

#discard does not give an error even the value is not present in the set
# Out:
# enter a value: 72
# set a before discard:  {0, 7, 14, 49, 56, 28}
# set a after discard:  {0, 7, 14, 49, 56, 28}

# %% [markdown]
# 5. Consider the following dictionary:
# my_dict = {
#  "name": "<your name>",
#  "roll_no": "<your roll number>",
#  "branch": "<your branch>",
#  "age": <your age>,
#  "city": "<your home city>"
# }

# %%
my_dict = {
    "name": "Amisha Goyal",
    "roll_no": "1024170288",
    "branch": "CSE",
    "age": 24,
    "city": "Patiala"
}

# %% [markdown]
# i. Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by
# hand — use pop() or dictionary comprehension so the code would work for any dictionary).

# %%
my_dict["location"] = my_dict.pop("city")

print(my_dict)
# Out:
# {'name': 'Amisha Goyal', 'roll_no': '1024170288', 'branch': 'CSE', 'age': 24, 'location': 'Patiala'}

# %% [markdown]
# ii. Add a new key “cgpa” with your CGPA as its value.

# %%
my_dict["cgpa"] = 9.4

print(my_dict)
# Out:
# {'name': 'Amisha Goyal', 'roll_no': '1024170288', 'branch': 'CSE', 'age': 24, 'location': 'Patiala', 'cgpa': 9.4}

# %% [markdown]
# iii. Update the value of “age” by increasing it by 1.

# %%
my_dict["age"] = my_dict["age"] + 1

print(my_dict)
# Out:
# {'name': 'Amisha Goyal', 'roll_no': '1024170288', 'branch': 'CSE', 'age': 25, 'location': 'Patiala', 'cgpa': 9.4}

# %% [markdown]
# iv. Delete the “branch” key using two different methods in two separate copies of the dictionary: once
# with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what
# does each return?).

# %%
dict_pop = my_dict.copy()

removed = dict_pop.pop("branch")

print("Using pop():", dict_pop)
print("Removed value:", removed)
# Out:
# Using pop(): {'name': 'Amisha Goyal', 'roll_no': '1024170288', 'age': 25, 'location': 'Patiala', 'cgpa': 9.4}
# Removed value: CSE

# %%
dict_del = my_dict.copy()

del dict_del["branch"]

print("Using del:", dict_del)
# Out:
# Using del: {'name': 'Amisha Goyal', 'roll_no': '1024170288', 'age': 25, 'location': 'Patiala', 'cgpa': 9.4}

# %% [markdown]
# v. Iterate over your dictionary using .items() and print each key-value pair as “key → value”.

# %%
for key, value in my_dict.items():
    print(key, "->", value)
# Out:
# name -> Amisha Goyal
# roll_no -> 1024170288
# branch -> CSE
# age -> 25
# location -> Patiala
# cgpa -> 9.4

# %% [markdown]
# vi. Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence
# using the in keyword and print a safe fallback message instead of letting the program crash.

# %%
if "email" in my_dict:
    print("email:", my_dict["email"])
else:
    print("Email does not exist in the dictionary.")
# Out:
# Email does not exist in the dictionary.

# %% [markdown]
# vii. Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details.
# Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win”
# when both dictionaries share a key.

# %%
friend_dict = {
    "name": "rani",
    "roll_no": "12345678",
    "branch": "CSE",
    "age": 21,
    "city": "bathinda"
}

merged_dict = {**my_dict, **friend_dict}

print("Merged dictionary:", merged_dict)

# When both dictionaries have the same key, value from the second dictionary wins.
# Out:
# Merged dictionary: {'name': 'rani', 'roll_no': '12345678', 'branch': 'CSE', 'age': 21, 'location': 'Patiala', 'cgpa': 9.4, 'city': 'bathinda'}

# %% [markdown]
# viii. Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your
# original dictionary where the value is a string.

# %%
string_dict = {}

for key, value in my_dict.items():
    if isinstance(value, str):
        string_dict[key] = value

print(string_dict)
# Out:
# {'name': 'Amisha Goyal', 'roll_no': '1024170288', 'branch': 'CSE', 'location': 'Patiala'}
